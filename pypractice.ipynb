# %%
print('hi')
# Out:
# hi

# %%
print(33)
# Out:
# 33

# %%
print('%s' %('python start'))
# Out:
# python start

# %%
a,b=map(int,input().split())
if a>b:
    print('>')
elif a<b:
    print('<')
elif a==b:
    print('==')
else:
    pass

# %%
print(2)
# Out:
# 2

# %%
#1330
a,b=map(int,input().split())
if a>b:
    print('>')
elif a<b:
    print('<')
elif a==b:
    print('==')
else:
    pass
# Out:
# ==

# %%
#9498
s=int(input())
if (90<=s):
    print('A')
elif s>=80:
    print('B')
elif s>=70:
    print('C')
elif s>=60:
    print('D')
else:
    print('F')
# Out:
# C

# %%
#2753
year=int(input())

if year%4==0:
    if year%100 !=0 or  year%400==0:
        print(1)
    else:
        print(0)
else:
    print(0)
# Out:
# 0

# %%
#14681
x=int(input())
y=int(input())
if x>0:
    if y>0:
        print(1)
    elif y<0:
        print(4)
elif x<0:
    if y>0:
        print(2)
    elif y<0:
        print(3)
# Out:
# 4

# %%
#2884
H,M = map(int,input().split())
M=M-45
if M<0:
    H=H-1
    M=60+M
    if H-1<0:
        H=23
        print(H,M)
    else:
        print(H,M)

else:
    print(H,M)
# Out:
# 4 1

# %%
H,M = map(int,input().split())
if M>44:
    print(H,M-45)
elif M<45 and H>0:
    print(H-1, M+15)
else:
    print(23,M+15)
# Out:
# 3 0

# %%
#1000
A,B = map(int, input().split())
print(A+B)
# Out:
# 6

# %%
#1001
A,B= map(int,input().split())
print(A-B)
# Out:
# -2

# %%
#1008
A,B=map(int, input().split())
print(f'{A/B:.10f}')
# Out:
# 0.2222222222

# %%
#1330
A,B=map(int, input().split())
if A>B:
    print('>')
elif A<B:
    print('<')
elif A==B:
    print('==')
else:
    pass
# Out:
# 10%

# %%
#2739
N=int(input())
for i in range(1,10):
    print('%d * %d = %d' %(N,i,N*i))
    i=i+1
# Out:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
#1546
N=int(input())
R=map(int,input().split)

# %%
#2741
N=int(input())
for i in range(1,N+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#2438
N=int(input())
for i in range(1,N+1):
    print('%s' %('*'*i))
# Out:
# *
# **
# ***
# ****
# *****

# %%
#10171
print('''        \     /\ 
          )  ( \')
        (  /  )
         \(__)|''')
# Out:
#         \     /\
#           )  ( ')
#         (  /  )
#          \(__)|

# %%
#10998
A,B=map(int,input().split())
print('%d' %(A*B))
# Out:
# 6

# %%
#2439
N=int(input())
for i in range(1,N+1):
    print('%s%s' %(' '*(N-i), '*'*(i)))
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
#10869
A,B=map(int, input().split())
print(A+B)
print(A-B)
print(A*B)
print(A//B)
print(A%B)
# Out:
# 10
# -2
# 24
# 0
# 4

# %%
#################################################################
N,X=map(int,input().split())
a = input().split(' ')
for i in range(0, N):
    if int(a[i]) < int(X):
        print(a[i], end=' ')
# Out:
# 3 2

# %%
################################################10952 
while True:
    a,b=map(int,input().split())
    if a==0 and b==0:
        break
    print(a+b)
# Out:
# 2
# 5
# 7
# 17
# 7
# 0

# %%
################################################10951
while True:
    try:
        a,b=map(int,input().split())
        print(a+b)
    except:
        break

# %%
#11720
N=int(input())
nums=input()
sum=0
for i in nums:
    sum+=int(i)
print(sum)
# Out:
# 6

# %%
n=int(input())
nums=input()
sum=0
for i in range(0,n):
    sum += int(nums[i])
print(sum)
# Out:
# 6

# %%
#11654
N=input()
print(ord(N))
# Out:
# 102

# %%
#10950
N=int(input())
for _ in range(N):
    a,b=map(int,input().split())
    print(a+b)
# Out:
# 4
# 10

# %%
#2441
N=int(input())
for i in range(N):
    print('%s%s' %(i*' ',(N-i)*'*'))
# Out:
#      *****
#       ****
#        ***
#         **
#          *

# %%
#2920
a=input()
for i in range(6):

    if int(a[i])<int(a[i+1]):
        print('ascending')
    elif int(a[i])>int(a[i+1]):
        print('descending')
    else:
        print('mixed')
# Out:
# ascending
# ascending
# ascending
# ascending
# descending
# ascending

# %%
##############################2562                  i가 for문 안에 없어도 range만큼 인풋값을 받는다.
num_lst=[]
empty_lst=[]
for i in range(9):
    num_lst.append(int(input()))

result_lst=num_lst +empty_lst

for i in range(0,8):
    if num_lst[i]>num_lst[i+1]:

        num_lst[i+1]=num_lst[i]

print(num_lst[-1])
# Out:
# 9

# %%
for i in range(8):
    a=int(input())
    print(a)
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\yundh\OneDrive\바탕 화면\pypractice\pypractice.ipynb 셀 34 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/yundh/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/pypractice/pypractice.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> for i in range(8):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yundh/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/pypractice/pypractice.ipynb#X45sZmlsZQ%3D%3D?line=1'>2</a>     a=int(input())
#       <a href='vscode-notebook-cell:/c%3A/Users/yundh/OneDrive/%EB%B0%94%ED%83%95%20%ED%99%94%EB%A9%B4/pypractice/pypractice.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a>     print(a)
#
# ValueError: invalid literal for int() with base 10: ''
