# %%
print('hi')
# Out:
# hi

# %%
print(33)
# Out:
# 33

# %%
print('%s' %('python start'))
# Out:
# python start

# %%
a,b=map(int,input().split())
if a>b:
    print('>')
elif a<b:
    print('<')
elif a==b:
    print('==')
else:
    pass

# %%
print(2)
# Out:
# 2

# %%
#1330
a,b=map(int,input().split())
if a>b:
    print('>')
elif a<b:
    print('<')
elif a==b:
    print('==')
else:
    pass
# Out:
# ==

# %%
#9498
s=int(input())
if (90<=s):
    print('A')
elif s>=80:
    print('B')
elif s>=70:
    print('C')
elif s>=60:
    print('D')
else:
    print('F')
# Out:
# C
